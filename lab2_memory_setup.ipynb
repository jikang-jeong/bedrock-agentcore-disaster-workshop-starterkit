# %% [markdown]
# # 실습 2: Memory 구성
#
# ## 목표
# - Bedrock Agent Core Memory 생성
# - Short-term & Long-term Memory 이해
# - Semantic Strategy 설정

# %% [markdown]
# ## Memory 개념
#
# ### Short-term Memory (단기 메모리)
# - 현재 대화 세션 내에서만 유지
# - 빠른 응답 속도
# - 예: "방금 말한 주소가 어디였지?"
#
# ### Long-term Memory (장기 메모리)
# - 세션을 넘어 영구 저장
# - Semantic Search 지원
# - 예: "이전에 대응했던 화재 사례"
#
# ### Semantic Strategy
# - Vector 임베딩 기반
# - 유사한 상황 자동 검색
# - Namespace로 사용자별 격리

# %% [markdown]
# ## 2-1. 환경 변수 로드

# %%
import os
import boto3

REGION = os.environ.get('AWS_REGION', 'us-west-2')
print(f"🌍 Region: {REGION}")

# %% [markdown]
# ## 2-2. Memory 생성

# %%
from bedrock_agentcore_starter_toolkit.operations.memory.manager import MemoryManager
from bedrock_agentcore_starter_toolkit.operations.memory.models.strategies import SemanticStrategy

print("🧠 Memory 리소스 생성 중...")

memory_manager = MemoryManager(region_name=REGION)

memory = memory_manager.get_or_create_memory(
    name="customMemory",
    description="화재 대응 어시스턴트 메모리 저장소",
    strategies=[
        SemanticStrategy(
            name="semanticLongTermMemory",
            namespaces=['/actors/{actorId}'],
        )
    ],
    event_expiry_days=30
)

MEMORY_ID = memory.get('id')
print(f"\n✅ Memory 생성 완료!")
print(f"📝 Memory ID: {MEMORY_ID}")

# 환경 변수로 저장
os.environ['MEMORY_ID'] = MEMORY_ID

# %% [markdown]
# ## 2-3. Memory ID 저장 (중요!)

# %%
# %%writefile agent/deploy/runtime/config_memory.py
# Memory ID 저장
MEMORY_ID = "{MEMORY_ID}"
REGION = "{REGION}"

print(f"✅ Memory ID 저장 완료: {MEMORY_ID}")

# %%
# config_memory.py 파일에 실제 값 저장
with open('agent/deploy/runtime/config_memory.py', 'w') as f:
    f.write(f'# Memory ID 저장\n')
    f.write(f'MEMORY_ID = "{MEMORY_ID}"\n')
    f.write(f'REGION = "{REGION}"\n')

print(f"✅ config_memory.py 파일 생성 완료")
print(f"📝 Memory ID: {MEMORY_ID}")

# %% [markdown]
# ## 2-4. Memory 목록 확인

# %%
memories = memory_manager.list_memories()

print("📋 생성된 Memory 목록:\n")
for mem in memories:
    print(f"- ID: {mem.get('id')}")
    print(f"  Name: {mem.get('name')}")
    print(f"  Description: {mem.get('description')}")
    print()

# %% [markdown]
# ## ✅ 실습 2 완료!
#
# ### 생성된 파일
# - `agent/deploy/runtime/config_memory.py`
#
# ### 다음 단계
# 👉 **lab3_vector_database.ipynb**
